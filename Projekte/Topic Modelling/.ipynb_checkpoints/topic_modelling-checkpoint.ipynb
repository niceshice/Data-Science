# %%
import spacy
import os
import pandas as pd
import re

# %%
nlp = spacy.load("en_core_web_md")

# %%
# Define the folder path
folder_path = 'corpus_base'

# Initialize lists to store data
titles = []
categories = []
contents = []

date_pattern = r'\d{4}-\d{2}-\d{2} - \d{2}:\d{2}'
phone_pattern = r'\(\+\d*\)\s\d*\s\d*\s\d*'
mark_pattern = r'[A-Z]{4,}'
ref_pattern = r'\d+\w+\d+'

# Iterate over files in the folder
for file_name in os.listdir(folder_path):
    # Check if file has .txt extension
    if file_name.endswith('.txt'):
        file_path = os.path.join(folder_path, file_name)
        
        # Read the file
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()
            
            # Extract title, category, and content
            title = lines[0].strip()
            category = lines[1].strip()
            content_lines = lines[2:]  # Exclude the first two lines
            
            # Remove dates from content lines
            content_lines = [re.sub(date_pattern, '', line) for line in content_lines]
            
            # Remove .jpg from content lines
            content_lines = [re.sub(r'\*\.jpg', '', line) for line in content_lines]
            
            # Remove weird stuff
            content_lines = [re.sub(r'\/\S*', '', line) for line in content_lines]
            content_lines = [re.sub(phone_pattern, '', line) for line in content_lines]
            content_lines = [re.sub(mark_pattern, '', line) for line in content_lines]
            content_lines = [re.sub(ref_pattern, '', line) for line in content_lines]
            
            # Remove batches of 3 lines
            content_lines = [line for line in content_lines if not line.startswith((r'\d', 'LINK', 'EN'))]
            
            # Join the remaining lines to form the content
            content = ' '.join(content_lines).strip()            
            
            # Append data to lists
            titles.append(title)
            categories.append(category)
            contents.append(content)

# Create a pandas dataframe
data = {
    'title': titles,
    'category': categories,
    'content': contents
}

df = pd.DataFrame(data)
df
# Out:
#                                                   title  \
# 0     EU should cooperate more with US in Mediterran...
# 1                     Broader EU-China Relations Needed
# 2     Transport Committee demands EU-wide blacklist ...
# 3     Compliance with Hague tribunal is key to acces...
# 4     Commissioner Rehn defends "rigorous" framework...
# ...                                                 ...
# 7241       Basic rights for crime victims across the EU
# 7242  Mobile roaming: MEPs win deal with Council to ...
# 7243  Opening: President Schulz condemns Toulouse ki...
# 7244  Food aid for needy beyond 2013: Commission fol...
# 7245  Professor: EU's agricultural policy needs to b...
#
#                          category  \
# 0     Development and cooperation
# 1              External relations
# 2                       Transport
# 3              External relations
# 4              External relations
# ...                           ...
# 7241         Judicial cooperation
# 7242          Information society
# 7243                 Institutions
# 7244                  Agriculture
# 7245                  Environment
#
#                                                 content
# 0     MEPs are disappointed with the results achieve...
# 1     A longer-term trade strategy needs to be devis...
# 2     Following a number of serious air crashes earl...
# 3     Speaking to the Foreign Affairs Committee on 3...
# 4     Appearing before the Foreign Affairs Committee...
# ...                                                 ...
# 7241  Committees Civil Liberties, Justice and Home A...
# 7242  Committees Industry, Research and Energy\n \n ...
# 7243  Plenary sittings\n \n Andrew  BXL  STR    01  ...
# 7244  Plenary sittings\n \n Ján  BXL  STR    90  agr...
# 7245  A woman cropping corn salad at an organic farm...
#
# [7246 rows x 3 columns]

# %%
stopwords = nlp.Defaults.stop_words|{'%', '.', "?", "!", ",", "(", ")", ":", ";", "\"", "'", "=", "-", "--en", "http", "v0", "xml", "im-", "doc", "avi"}
stoptags = ['ADV','PRON','CCONJ','PUNCT','PART','DET','ADP','SPACE', 'NUM', 'SYM']

# %%
df["tokens"] = df.content.apply(lambda x: [t.lemma_.lower() for t in nlp(x, disable=["parser", "ner"]) if (t.text.strip() != "" and (t.text.lower() not in stopwords) and t.pos_ not in stoptags)])

# %%
df.iloc[356].tokens
# Out:
# ['united',
#  'kingdom',
#  'hastings',
#  'beach',
#  'january',
#  'month',
#  'think',
#  'take',
#  'dip',
#  'sea',
#  'dream',
#  'summer',
#  'holiday',
#  'recognise',
#  'bathe',
#  'beach',
#  'eu',
#  'thank',
#  'european',
#  'bathing',
#  'water',
#  'directive',
#  'system',
#  'place',
#  'minimum',
#  'standard',
#  'cleanliness',
#  'water',
#  'swim',
#  'information',
#  'help',
#  'choose',
#  'beach',
#  'bathe',
#  'mep',
#  'vote',
#  'revise',
#  'directive',
#  'update',
#  'rule',
#  'raise',
#  'standard',
#  'improve',
#  'information',
#  'public',
#  'vote',
#  'place',
#  'strasbourg',
#  'january',
#  'text',
#  'agree',
#  'delegation',
#  'mep',
#  'environment',
#  'ministers',
#  'eu',
#  'member',
#  'states',
#  'new',
#  'directive',
#  'come',
#  'effect',
#  'figure',
#  'european',
#  'commission',
#  'show',
#  '%',
#  'uk',
#  'coastal',
#  'bathing',
#  'water',
#  'meet',
#  'minimum',
#  'quality',
#  'criterion',
#  'set',
#  'directive',
#  'slight',
#  'fall',
#  'number',
#  'progress',
#  'meet',
#  'directive',
#  'stringent',
#  'voluntary',
#  'standard',
#  'dramatic',
#  'environment',
#  'agency',
#  'england',
#  'wales',
#  'claim',
#  '%',
#  'bathing',
#  'water',
#  'england',
#  'wales',
#  'meet',
#  'strict',
#  'standard',
#  'result',
#  'publish',
#  'scottish',
#  'environment',
#  'protection',
#  'agency',
#  'beach',
#  'meet',
#  'tough',
#  'excellent',
#  'criterion',
#  'beach',
#  'england',
#  'scotland',
#  'wales',
#  'claim',
#  'famous',
#  'blue',
#  'flag',
#  'cleanliness',
#  'directive',
#  'standard',
#  'requirement',
#  'mid',
#  'season',
#  'health',
#  'check',
#  'summer',
#  'marine',
#  'conservation',
#  'society',
#  'show',
#  'designate',
#  'beach',
#  'fail',
#  'meet',
#  'voluntary',
#  'standard',
#  'beach',
#  'uk',
#  'match',
#  'directive',
#  'minimum',
#  'standard',
#  'new',
#  'directive',
#  'discuss',
#  'mep',
#  'month',
#  'affect',
#  'uk',
#  'bathing',
#  'water',
#  'simplify',
#  'test',
#  'focus',
#  'type',
#  'bacteria:-',
#  'e.coli',
#  'intestinal',
#  'enterococchi',
#  'different',
#  'test',
#  'bring',
#  'extra',
#  'classification',
#  'sufficient',
#  'quality',
#  'come',
#  'excellent',
#  'good',
#  'allow',
#  'beach',
#  'qualify',
#  'bathe',
#  'water',
#  'standard',
#  'raise',
#  'health',
#  'risk',
#  'bather',
#  'reduce',
#  'test',
#  'carry',
#  'beach',
#  'classify',
#  'poor',
#  'sufficient',
#  'information',
#  'water',
#  'quality',
#  'provide',
#  'internet',
#  'year',
#  'date',
#  'finding',
#  'regular',
#  'test',
#  'available',
#  'new',
#  'standard',
#  'sign',
#  'devise',
#  'place',
#  'bathe',
#  'site',
#  'indicate',
#  'quality',
#  'water',
#  'uk',
#  'beach',
#  'smiley',
#  'system',
#  'face',
#  'indicate',
#  'good',
#  'poor',
#  'quality',
#  'water',
#  'exist',
#  'display',
#  'board',
#  'beach',
#  'directive',
#  'adopt',
#  'european',
#  'parliament',
#  'elect',
#  'little',
#  'content',
#  'rule',
#  'time',
#  'thing',
#  'different',
#  'european',
#  'parliament',
#  'share',
#  'equal',
#  'power',
#  'council',
#  'ministers',
#  'decide',
#  'final',
#  'text',
#  'new',
#  'directive',
#  'mep',
#  'claim',
#  'achieve',
#  'strong',
#  'directive',
#  'environment',
#  'great',
#  'clarity',
#  'information',
#  'available',
#  'general',
#  'public',
#  'european',
#  'parliament',
#  'amendment',
#  'focus',
#  'particular',
#  'criterion',
#  'new',
#  'sufficient',
#  'category',
#  'quality',
#  'information',
#  'public',
#  'emergency',
#  'plan',
#  'bathe',
#  'water',
#  'classify',
#  'sufficient',
#  'poor',
#  'mep',
#  'lobby',
#  'key',
#  'piece',
#  'legislation',
#  'group',
#  'diverse',
#  'surfers',
#  'sewage',
#  'cornwall',
#  'base',
#  'group',
#  'want',
#  'directive',
#  'extend',
#  'bathe',
#  'recreational',
#  'activity',
#  'watervoice',
#  'consumer',
#  'council',
#  'water',
#  'represent',
#  'water',
#  'sewerage',
#  'customer',
#  'england',
#  'wales',
#  'argue',
#  'new',
#  'directive',
#  'increase',
#  'water',
#  'price',
#  'claim',
#  'english',
#  'welsh',
#  'beach',
#  'fail',
#  'meet',
#  'new',
#  'minimum',
#  'standard',
#  'lay',
#  'directive',
#  'environmental',
#  'fact',
#  'figure',
#  'bathe',
#  'water',
#  'quality',
#  'website',
#  'propose',
#  'change',
#  'bathing',
#  'water',
#  'directive',
#  'surfers',
#  'sewage',
#  'campaign',
#  'clean',
#  'safe',
#  'recreational',
#  'water',
#  'free',
#  'sewage',
#  'effluent',
#  'toxic',
#  'chemical',
#  'nuclear',
#  'waste',
#  'consumer',
#  'council',
#  'water']

# %%
from gensim.corpora.dictionary import Dictionary
dictionary = Dictionary(df['tokens'])
dictionary.filter_extremes(no_below=3, no_above=0.2)

# %%
corpus = [dictionary.doc2bow(a) for a in df['tokens']]

# %%
from gensim.models import LdaMulticore

# %%
# We will execute topic modeling 50 times, each time with the different number of topics
max_topics = 50 
models = []

for i in range(max_topics):
    print("Training LDA with " + str(i+1) + " topics.")
    
    lda_model = LdaMulticore(corpus=corpus, id2word=dictionary, iterations=100, num_topics=i+1, workers = 4, random_state=100)
    models.append(lda_model)
          
print("Done.")
# Out:
# Training LDA with 1 topics.
# Training LDA with 2 topics.
# Training LDA with 3 topics.
# Training LDA with 4 topics.
# Training LDA with 5 topics.
# Training LDA with 6 topics.
# Training LDA with 7 topics.
# Training LDA with 8 topics.
# Training LDA with 9 topics.
# Training LDA with 10 topics.
# Training LDA with 11 topics.
# Training LDA with 12 topics.
# Training LDA with 13 topics.
# Training LDA with 14 topics.
# Training LDA with 15 topics.
# Training LDA with 16 topics.
# Training LDA with 17 topics.
# Training LDA with 18 topics.
# Training LDA with 19 topics.
# Training LDA with 20 topics.
# Training LDA with 21 topics.
# Training LDA with 22 topics.
# Training LDA with 23 topics.
# Training LDA with 24 topics.
# Training LDA with 25 topics.
# Training LDA with 26 topics.
# Training LDA with 27 topics.
# Training LDA with 28 topics.
# Training LDA with 29 topics.
# Training LDA with 30 topics.
# Training LDA with 31 topics.
# Training LDA with 32 topics.
# Training LDA with 33 topics.
# Training LDA with 34 topics.
# Training LDA with 35 topics.
# Training LDA with 36 topics.
# Training LDA with 37 topics.
# Training LDA with 38 topics.
# Training LDA with 39 topics.
# Training LDA with 40 topics.
# Training LDA with 41 topics.
# Training LDA with 42 topics.
# Training LDA with 43 topics.
# Training LDA with 44 topics.
# Training LDA with 45 topics.
# Training LDA with 46 topics.
# Training LDA with 47 topics.
# Training LDA with 48 topics.
# Training LDA with 49 topics.
# Training LDA with 50 topics.
# Done.

# %%
from gensim.models import CoherenceModel

coherence_measures = ['c_uci', 'u_mass', 'c_v', 'c_uci', 'c_npmi']
scores = []
for measure in coherence_measures:
    for i in range(len(models)):
        print("Computing " + str(measure) +" for the LDA model with " + str(i+1) + " topics.")
        cm = CoherenceModel(model=models[i], corpus=corpus, texts = df["tokens"], dictionary=dictionary, coherence=measure)
        score = cm.get_coherence()
        scores.append(score)
    print("Done with " + j)
print("Done.")
# Out:
# Computing c_uci for the LDA model with 1 topics.
# Done.
# Computing c_uci for the LDA model with 2 topics.
# Done.
# Computing c_uci for the LDA model with 3 topics.
# Done.
# Computing c_uci for the LDA model with 4 topics.
# Done.
# Computing c_uci for the LDA model with 5 topics.
# Done.
# Computing c_uci for the LDA model with 6 topics.
# Done.
# Computing c_uci for the LDA model with 7 topics.
# Done.
# Computing c_uci for the LDA model with 8 topics.
# Done.
# Computing c_uci for the LDA model with 9 topics.
# Done.
# Computing c_uci for the LDA model with 10 topics.
# Done.
# Computing c_uci for the LDA model with 11 topics.
# Done.
# Computing c_uci for the LDA model with 12 topics.
# Done.
# Computing c_uci for the LDA model with 13 topics.
# Done.
# Computing c_uci for the LDA model with 14 topics.
# Done.
# Computing c_uci for the LDA model with 15 topics.
# Done.
# Computing c_uci for the LDA model with 16 topics.
# Done.
# Computing c_uci for the LDA model with 17 topics.
# Done.
# Computing c_uci for the LDA model with 18 topics.
# Done.
# Computing c_uci for the LDA model with 19 topics.
# Done.
# Computing c_uci for the LDA model with 20 topics.
# Done.
# Computing c_uci for the LDA model with 21 topics.
# Done.
# Computing c_uci for the LDA model with 22 topics.
# Done.
# Computing c_uci for the LDA model with 23 topics.
# Done.
# Computing c_uci for the LDA model with 24 topics.
# Done.
# Computing c_uci for the LDA model with 25 topics.
# Done.
# Computing c_uci for the LDA model with 26 topics.
# Done.
# Computing c_uci for the LDA model with 27 topics.
# Done.
# Computing c_uci for the LDA model with 28 topics.
# Done.
# Computing c_uci for the LDA model with 29 topics.
# Done.
# Computing c_uci for the LDA model with 30 topics.
# Done.
# Computing c_uci for the LDA model with 31 topics.
# Done.
# Computing c_uci for the LDA model with 32 topics.
# Done.
# Computing c_uci for the LDA model with 33 topics.
# Done.
# Computing c_uci for the LDA model with 34 topics.
# Done.
# Computing c_uci for the LDA model with 35 topics.
# Done.
# Computing c_uci for the LDA model with 36 topics.
# Done.
# Computing c_uci for the LDA model with 37 topics.
# Done.
# Computing c_uci for the LDA model with 38 topics.
# Done.
# Computing c_uci for the LDA model with 39 topics.
# Done.
# Computing c_uci for the LDA model with 40 topics.
# Done.
# Computing c_uci for the LDA model with 41 topics.
# Done.
# Computing c_uci for the LDA model with 42 topics.
# Done.
# Computing c_uci for the LDA model with 43 topics.
# Done.
# Computing c_uci for the LDA model with 44 topics.
# Done.
# Computing c_uci for the LDA model with 45 topics.
# Done.
# Computing c_uci for the LDA model with 46 topics.
# Done.
# Computing c_uci for the LDA model with 47 topics.
# Done.
# Computing c_uci for the LDA model with 48 topics.
# Done.
# Computing c_uci for the LDA model with 49 topics.
# Done.
# Computing c_uci for the LDA model with 50 topics.
# Done.
# Computing u_mass for the LDA model with 1 topics.
# Done.
# Computing u_mass for the LDA model with 2 topics.
# Done.
# Computing u_mass for the LDA model with 3 topics.
# Done.
# Computing u_mass for the LDA model with 4 topics.
# Done.
# Computing u_mass for the LDA model with 5 topics.
# Done.
# Computing u_mass for the LDA model with 6 topics.
# Done.
# Computing u_mass for the LDA model with 7 topics.
# Done.
# Computing u_mass for the LDA model with 8 topics.
# Done.
# Computing u_mass for the LDA model with 9 topics.
# Done.
# Computing u_mass for the LDA model with 10 topics.
# Done.
# Computing u_mass for the LDA model with 11 topics.
# Done.
# Computing u_mass for the LDA model with 12 topics.
# Done.
# Computing u_mass for the LDA model with 13 topics.
# Done.
# Computing u_mass for the LDA model with 14 topics.
# Done.
# Computing u_mass for the LDA model with 15 topics.
# Done.
# Computing u_mass for the LDA model with 16 topics.
# Done.
# Computing u_mass for the LDA model with 17 topics.
# Done.
# Computing u_mass for the LDA model with 18 topics.
# Done.
# Computing u_mass for the LDA model with 19 topics.
# Done.
# Computing u_mass for the LDA model with 20 topics.
# Done.
# Computing u_mass for the LDA model with 21 topics.
# Done.
# Computing u_mass for the LDA model with 22 topics.
# Done.
# Computing u_mass for the LDA model with 23 topics.
# Done.
# Computing u_mass for the LDA model with 24 topics.
# Done.
# Computing u_mass for the LDA model with 25 topics.
# Done.
# Computing u_mass for the LDA model with 26 topics.
# Done.
# Computing u_mass for the LDA model with 27 topics.
# Done.
# Computing u_mass for the LDA model with 28 topics.
# Done.
# Computing u_mass for the LDA model with 29 topics.
# Done.
# Computing u_mass for the LDA model with 30 topics.
# Done.
# Computing u_mass for the LDA model with 31 topics.
# Done.
# Computing u_mass for the LDA model with 32 topics.
# Done.
# Computing u_mass for the LDA model with 33 topics.
# Done.
# Computing u_mass for the LDA model with 34 topics.
# Done.
# Computing u_mass for the LDA model with 35 topics.
# Done.
# Computing u_mass for the LDA model with 36 topics.
# Done.
# Computing u_mass for the LDA model with 37 topics.
# Done.
# Computing u_mass for the LDA model with 38 topics.
# Done.
# Computing u_mass for the LDA model with 39 topics.
# Done.
# Computing u_mass for the LDA model with 40 topics.
# Done.
# Computing u_mass for the LDA model with 41 topics.
# Done.
# Computing u_mass for the LDA model with 42 topics.
# Done.
# Computing u_mass for the LDA model with 43 topics.
# Done.
# Computing u_mass for the LDA model with 44 topics.
# Done.
# Computing u_mass for the LDA model with 45 topics.
# Done.
# Computing u_mass for the LDA model with 46 topics.
# Done.
# Computing u_mass for the LDA model with 47 topics.
# Done.
# Computing u_mass for the LDA model with 48 topics.
# Done.
# Computing u_mass for the LDA model with 49 topics.
# Done.
# Computing u_mass for the LDA model with 50 topics.
# Done.
# Computing c_v for the LDA model with 1 topics.
# Done.
# Computing c_v for the LDA model with 2 topics.
# Done.
# Computing c_v for the LDA model with 3 topics.
# Done.
# Computing c_v for the LDA model with 4 topics.
# Done.
# Computing c_v for the LDA model with 5 topics.
# Done.
# Computing c_v for the LDA model with 6 topics.
# Done.
# Computing c_v for the LDA model with 7 topics.
# Done.
# Computing c_v for the LDA model with 8 topics.
# Done.
# Computing c_v for the LDA model with 9 topics.
# Done.
# Computing c_v for the LDA model with 10 topics.
# Done.
# Computing c_v for the LDA model with 11 topics.
# Done.
# Computing c_v for the LDA model with 12 topics.
# Done.
# Computing c_v for the LDA model with 13 topics.
# Done.
# Computing c_v for the LDA model with 14 topics.
# Done.
# Computing c_v for the LDA model with 15 topics.
# Done.
# Computing c_v for the LDA model with 16 topics.
# Done.
# Computing c_v for the LDA model with 17 topics.
# Done.
# Computing c_v for the LDA model with 18 topics.
# Done.
# Computing c_v for the LDA model with 19 topics.
# Done.
# Computing c_v for the LDA model with 20 topics.
# Done.
# Computing c_v for the LDA model with 21 topics.
# Done.
# Computing c_v for the LDA model with 22 topics.
# Done.
# Computing c_v for the LDA model with 23 topics.
# Done.
# Computing c_v for the LDA model with 24 topics.
# Done.
# Computing c_v for the LDA model with 25 topics.
# Done.
# Computing c_v for the LDA model with 26 topics.
# Done.
# Computing c_v for the LDA model with 27 topics.
# Done.
# Computing c_v for the LDA model with 28 topics.
# Done.
# Computing c_v for the LDA model with 29 topics.
# Done.
# Computing c_v for the LDA model with 30 topics.
# Done.
# Computing c_v for the LDA model with 31 topics.
# Done.
# Computing c_v for the LDA model with 32 topics.
# Done.
# Computing c_v for the LDA model with 33 topics.
# Done.
# Computing c_v for the LDA model with 34 topics.
# Done.
# Computing c_v for the LDA model with 35 topics.
# Done.
# Computing c_v for the LDA model with 36 topics.
# Done.
# Computing c_v for the LDA model with 37 topics.
# Done.
# Computing c_v for the LDA model with 38 topics.
# Done.
# Computing c_v for the LDA model with 39 topics.
# Done.
# Computing c_v for the LDA model with 40 topics.
# Done.
# Computing c_v for the LDA model with 41 topics.
# Done.
# Computing c_v for the LDA model with 42 topics.
# Done.
# Computing c_v for the LDA model with 43 topics.
# Done.
# Computing c_v for the LDA model with 44 topics.
# Done.
# Computing c_v for the LDA model with 45 topics.
# Done.
# Computing c_v for the LDA model with 46 topics.
# Done.
# Computing c_v for the LDA model with 47 topics.
# Done.
# Computing c_v for the LDA model with 48 topics.
# Done.
# Computing c_v for the LDA model with 49 topics.
# Done.
# Computing c_v for the LDA model with 50 topics.
# Done.
# Computing c_uci for the LDA model with 1 topics.
# Done.
# Computing c_uci for the LDA model with 2 topics.
# Done.
# Computing c_uci for the LDA model with 3 topics.
# Done.
# Computing c_uci for the LDA model with 4 topics.
# Done.
# Computing c_uci for the LDA model with 5 topics.
# Done.
# Computing c_uci for the LDA model with 6 topics.
# Done.
# Computing c_uci for the LDA model with 7 topics.
# Done.
# Computing c_uci for the LDA model with 8 topics.
# Done.
# Computing c_uci for the LDA model with 9 topics.
# Done.
# Computing c_uci for the LDA model with 10 topics.
# Done.
# Computing c_uci for the LDA model with 11 topics.
# Done.
# Computing c_uci for the LDA model with 12 topics.
# Done.
# Computing c_uci for the LDA model with 13 topics.
# Done.
# Computing c_uci for the LDA model with 14 topics.
# Done.
# Computing c_uci for the LDA model with 15 topics.
# Done.
# Computing c_uci for the LDA model with 16 topics.
# Done.
# Computing c_uci for the LDA model with 17 topics.
# Done.
# Computing c_uci for the LDA model with 18 topics.
# Done.
# Computing c_uci for the LDA model with 19 topics.
# Done.
# Computing c_uci for the LDA model with 20 topics.
# Done.
# Computing c_uci for the LDA model with 21 topics.
# Done.
# Computing c_uci for the LDA model with 22 topics.
# Done.
# Computing c_uci for the LDA model with 23 topics.
# Done.
# Computing c_uci for the LDA model with 24 topics.
# Done.
# Computing c_uci for the LDA model with 25 topics.
# Done.
# Computing c_uci for the LDA model with 26 topics.
# Done.
# Computing c_uci for the LDA model with 27 topics.
# Done.
# Computing c_uci for the LDA model with 28 topics.
# Done.
# Computing c_uci for the LDA model with 29 topics.
# Done.
# Computing c_uci for the LDA model with 30 topics.
# Done.
# Computing c_uci for the LDA model with 31 topics.
# Done.
# Computing c_uci for the LDA model with 32 topics.
# Done.
# Computing c_uci for the LDA model with 33 topics.
# Done.
# Computing c_uci for the LDA model with 34 topics.
# Done.
# Computing c_uci for the LDA model with 35 topics.
# Done.
# Computing c_uci for the LDA model with 36 topics.
# Done.
# Computing c_uci for the LDA model with 37 topics.
# Done.
# Computing c_uci for the LDA model with 38 topics.
# Done.
# Computing c_uci for the LDA model with 39 topics.
# Done.
# Computing c_uci for the LDA model with 40 topics.
# Done.
# Computing c_uci for the LDA model with 41 topics.
# Done.
# Computing c_uci for the LDA model with 42 topics.
# Done.
# Computing c_uci for the LDA model with 43 topics.
# Done.
# Computing c_uci for the LDA model with 44 topics.
# Done.
# Computing c_uci for the LDA model with 45 topics.
# Done.
# Computing c_uci for the LDA model with 46 topics.
# Done.
# Computing c_uci for the LDA model with 47 topics.
# Done.
# Computing c_uci for the LDA model with 48 topics.
# Done.
# Computing c_uci for the LDA model with 49 topics.
# Done.
# Computing c_uci for the LDA model with 50 topics.
# Done.
# Computing c_npmi for the LDA model with 1 topics.
# Done.
# Computing c_npmi for the LDA model with 2 topics.
# Done.
# Computing c_npmi for the LDA model with 3 topics.
# Done.
# Computing c_npmi for the LDA model with 4 topics.
# Done.
# Computing c_npmi for the LDA model with 5 topics.
# Done.
# Computing c_npmi for the LDA model with 6 topics.
# Done.
# Computing c_npmi for the LDA model with 7 topics.
# Done.
# Computing c_npmi for the LDA model with 8 topics.
# Done.
# Computing c_npmi for the LDA model with 9 topics.
# Done.
# Computing c_npmi for the LDA model with 10 topics.
# Done.
# Computing c_npmi for the LDA model with 11 topics.
# Done.
# Computing c_npmi for the LDA model with 12 topics.
# Done.
# Computing c_npmi for the LDA model with 13 topics.
# Done.
# Computing c_npmi for the LDA model with 14 topics.
# Done.
# Computing c_npmi for the LDA model with 15 topics.
# Done.
# Computing c_npmi for the LDA model with 16 topics.
# Done.
# Computing c_npmi for the LDA model with 17 topics.
# Done.
# Computing c_npmi for the LDA model with 18 topics.
# Done.
# Computing c_npmi for the LDA model with 19 topics.
# Done.
# Computing c_npmi for the LDA model with 20 topics.
# Done.
# Computing c_npmi for the LDA model with 21 topics.
# Done.
# Computing c_npmi for the LDA model with 22 topics.
# Done.
# Computing c_npmi for the LDA model with 23 topics.
# Done.
# Computing c_npmi for the LDA model with 24 topics.
# Done.
# Computing c_npmi for the LDA model with 25 topics.
# Done.
# Computing c_npmi for the LDA model with 26 topics.
# Done.
# Computing c_npmi for the LDA model with 27 topics.
# Done.
# Computing c_npmi for the LDA model with 28 topics.
# Done.
# Computing c_npmi for the LDA model with 29 topics.
# Done.
# Computing c_npmi for the LDA model with 30 topics.
# Done.
# Computing c_npmi for the LDA model with 31 topics.
# Done.
# Computing c_npmi for the LDA model with 32 topics.
# Done.
# Computing c_npmi for the LDA model with 33 topics.
# Done.
# Computing c_npmi for the LDA model with 34 topics.
# Done.
# Computing c_npmi for the LDA model with 35 topics.
# Done.
# Computing c_npmi for the LDA model with 36 topics.
# Done.
# Computing c_npmi for the LDA model with 37 topics.
# Done.
# Computing c_npmi for the LDA model with 38 topics.
# Done.
# Computing c_npmi for the LDA model with 39 topics.
# Done.
# Computing c_npmi for the LDA model with 40 topics.
# Done.
# Computing c_npmi for the LDA model with 41 topics.
# Done.
# Computing c_npmi for the LDA model with 42 topics.
# Done.
# Computing c_npmi for the LDA model with 43 topics.
# Done.
# Computing c_npmi for the LDA model with 44 topics.
# Done.
# Computing c_npmi for the LDA model with 45 topics.
# Done.
# Computing c_npmi for the LDA model with 46 topics.
# Done.
# Computing c_npmi for the LDA model with 47 topics.
# Done.
# Computing c_npmi for the LDA model with 48 topics.
# Done.
# Computing c_npmi for the LDA model with 49 topics.
# Done.
# Computing c_npmi for the LDA model with 50 topics.
# Done.

# %%
import matplotlib.pyplot as plt

# still bs
num_topics = [i+1 for i in range(len(scores))]
                                
_=plt.plot(num_topics, scores)
_=plt.xlabel('Number of Topics')
_=plt.ylabel('Coherence Score')
_=plt.title('uci')
plt.show()

# %%
models[3].print_topics(num_words = 5)
# Out:
# [(0,
#   '0.003*"election" + 0.003*"climate" + 0.003*"delegation" + 0.002*"consumer" + 0.002*"transport"'),
#  (1,
#   '0.004*"woman" + 0.003*"climate" + 0.003*"food" + 0.002*"euro" + 0.002*"child"'),
#  (2,
#   '0.004*"delegation" + 0.002*"election" + 0.002*"fr" + 0.002*"transport" + 0.002*"research"'),
#  (3,
#   '0.003*"product" + 0.002*"presidency" + 0.002*"food" + 0.002*"prize" + 0.002*"freedom"')]
